# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Aayan-Farooq/FlyRank-AI-Week-1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
I chose **Lane 2: Refresh / Content Opportunity Scoring
This lane focuses on identifying which pages should be reviewed first for content refresh or improvement. I selected this lane because the starter dataset already contains search performance metrics such as impressions, clicks, CTR, sessions, content age, and trend direction. These observable signals provide evidence that can help prioritize pages for review.5
Rather than replacing human decision-making, the goal is to produce a ranked recommendation list that helps SEO teams spend their limited time on the pages most likely to benefit from review.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
Which pages should be reviewed first for refresh, expansion, or monitoring based on their historical search performance?

### Decision

Should this page be prioritized for review?

### Unit of Analysis

One row represents one content page.

### Output

A ranked list of pages with a confidence score and explanation for why each page deserves review.

### Action

An SEO or content team can review the highest-ranked pages first, update outdated content, improve titles or metadata, expand thin content, or monitor performance.

### Cost of a Wrong Recommendation

If a healthy page is incorrectly prioritized, reviewers waste valuable time.

If a declining page is missed, an opportunity to improve search performance and traffic may be lost.

### Why Machine Learning Helps

The dataset contains many observable signals that interact in complex ways. Machine learning can combine these signals to rank pages more effectively than a single manually designed rule while still supporting—not replacing—human judgment.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
print(df.shape)

print(df["impressions_90d"].describe())

print(df["clicks_90d"].describe())

print(df["sessions_90d"].describe())

print((df["trend_direction"] == "down").mean())

# %% [markdown]
# ## Quick Look at the Data
#
# The starter dataset contains **_____** pages.
#
# Average impressions over the last 90 days are **_____**.
#
# Average clicks over the last 90 days are **_____**.
#
# Approximately **_____ %** of pages are labeled as declining.
#
# These statistics suggest that there is enough variation in search performance to investigate which pages should be prioritized for review.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
This notebook identifies pages that appear to be stronger candidates for review based on historical search signals.

The analysis does not prove that refreshing a page will increase traffic.

The model identifies patterns in historical data that may help prioritize review efforts.

Correlation should not be interpreted as causation, and final decisions should always involve human review.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [✅] Every section above is filled — markdown thinking AND the code that backs it
# - [ ✅] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ✅] No client names, URLs, or private queries anywhere
# - [✅ ] My claims use careful words: observed, measured, directional, decision-support
# - [✅ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
